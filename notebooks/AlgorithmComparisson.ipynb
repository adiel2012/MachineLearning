# %% [markdown]
# # Statistical Tests for Comparing Algorithm Accuracy
#
# ## 1. ANOVA (Analysis of Variance)
# **Purpose**: ANOVA tests for significant differences between the means of three or more groups.
#
# **When to Use**:
# - Comparing the performance of multiple algorithms on different datasets.
# - Assumes the data is normally distributed and variances are equal (homogeneity of variances).
#
# **How It Works**:
# - **One-Way ANOVA**: Tests if there is a difference in the mean accuracy across different algorithms or datasets.
# - **Two-Way ANOVA**: Tests the effect of two independent variables (e.g., algorithms and datasets) on accuracy, and also examines interaction effects.
#
# **Steps**:
# 1. Calculate the mean accuracy for each group.
# 2. Compute the overall mean accuracy.
# 3. Determine the variance within each group and between groups.
# 4. Use the F-ratio to test the null hypothesis that all group means are equal.
#
# **Interpretation**:
# - **F-ratio**: A large F-ratio indicates that there is more variance between groups than within groups, suggesting a significant difference.
# - **p-value**: If the p-value is less than the significance level (e.g., 0.05), reject the null hypothesis.
#
# **Post-Hoc Tests** (if ANOVA is significant):
# - **Tukey's HSD (Honest Significant Difference)**: Compares all possible pairs of means.
# - **Bonferroni Correction**: Adjusts the significance level when multiple comparisons are made to control the family-wise error rate.
#
# ## 2. Paired t-test
# **Purpose**: Compares the means of two related groups to determine if there is a significant difference between them.
#
# **When to Use**:
# - Comparing the accuracy of two algorithms on the same set of datasets (repeated measures).
#
# **How It Works**:
# 1. Compute the difference between each pair of measurements (e.g., accuracy scores of two algorithms on the same dataset).
# 2. Calculate the mean and standard deviation of these differences.
# 3. Use the t-statistic to determine if the mean difference is significantly different from zero.
#
# **Steps**:
# 1. Calculate the differences between paired observations.
# 2. Compute the mean and standard deviation of these differences.
# 3. Use the t-statistic formula to test the null hypothesis that the mean difference is zero.
#
# **Interpretation**:
# - **t-value**: A large t-value indicates a greater difference between the paired means.
# - **p-value**: If the p-value is less than the significance level, reject the null hypothesis.
#
# ## 3. Kruskal-Wallis Test
# **Purpose**: A non-parametric test used to compare the medians of three or more independent groups.
#
# **When to Use**:
# - When the data does not meet the assumptions of normality or when using ordinal data.
#
# **How It Works**:
# 1. Rank all data points from all groups together.
# 2. Calculate the sum of ranks for each group.
# 3. Compute the test statistic using the ranks and group sizes.
#
# **Steps**:
# 1. Rank the combined data from all groups.
# 2. Calculate the sum of ranks for each group.
# 3. Use the Kruskal-Wallis H statistic to test the null hypothesis that all group medians are equal.
#
# **Interpretation**:
# - **H-statistic**: A large H-statistic indicates significant differences between groups.
# - **p-value**: If the p-value is less than the significance level, reject the null hypothesis.
#
# ## 4. Wilcoxon Signed-Rank Test
# **Purpose**: A non-parametric test for comparing the medians of two related groups.
#
# **When to Use**:
# - Comparing the accuracy of two algorithms on the same set of datasets when data does not meet the assumptions of normality.
#
# **How It Works**:
# 1. Calculate the differences between paired observations.
# 2. Rank the absolute values of the differences.
# 3. Sum the ranks for positive and negative differences separately.
#
# **Steps**:
# 1. Find the differences between paired observations and rank the absolute values.
# 2. Calculate the sum of ranks for positive and negative differences.
# 3. Use the Wilcoxon signed-rank statistic to test the null hypothesis that the median difference is zero.
#
# **Interpretation**:
# - **W-statistic**: A large deviation from zero indicates a significant difference between the medians.
# - **p-value**: If the p-value is less than the significance level, reject the null hypothesis.
#
# ## 5. Friedman Test
# **Purpose**: A non-parametric test used to compare more than two related groups.
#
# **When to Use**:
# - Comparing multiple algorithms across the same set of datasets (repeated measures).
#
# **How It Works**:
# 1. Rank each set of related observations.
# 2. Calculate the test statistic based on the sum of ranks and the number of groups.
#
# **Steps**:
# 1. Rank the data for each group.
# 2. Compute the sum of ranks for each group.
# 3. Calculate the Friedman chi-square statistic to test the null hypothesis that all group medians are equal.
#
# **Interpretation**:
# - **Chi-Square Statistic**: A large value indicates significant differences between groups.
# - **p-value**: If the p-value is less than the significance level, reject the null hypothesis.
#
# ## Bonferroni-Dunn Correction
# **Purpose**: Adjusts the significance level to control the family-wise error rate when performing multiple comparisons.
#
# **When to Use**:
# - When performing multiple pairwise comparisons after finding a significant result with ANOVA or Friedman test.
#
# **How It Works**:
# 1. Divide the desired significance level (e.g., 0.05) by the number of comparisons.
# 2. Use the adjusted significance level to determine if each pairwise comparison is statistically significant.
#
# **Steps**:
# 1. Calculate the number of comparisons $ \frac{k(k-1)}{2} $ for $ k $ groups.
# 2. Adjust the significance level: $ \alpha_{adjusted} = \frac{\alpha}{\text{number of comparisons}} $.
# 3. Compare the p-values of the pairwise comparisons to the adjusted significance level.
#
# **Interpretation**:
# - If the p-value of a pairwise comparison is less than the adjusted significance level, the difference is considered statistically significant.
#
# ### References
# - Dunn, O. J. (1961). "Multiple comparisons among means." *Journal of the American Statistical Association*, 56(293), 52-64.
# - Demšar, J. (2006). "Statistical Comparisons of Classifiers over Multiple Data Sets." *Journal of Machine Learning Research*, 7, 1-30.
# - García, S., Fernández, A., Luengo, J., & Herrera, F. (2010). "Advanced nonparametric tests for multiple comparisons in the design of experiments in computational intelligence and data mining: Experimental analysis of power." *Information Sciences*, 180(10), 2044-2064.

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn scipy statsmodels
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_rel, kruskal, wilcoxon, friedmanchisquare, ranksums
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multitest import multipletests
from sklearn.datasets import make_classification, make_circles, make_moons, make_blobs
from itertools import combinations
import warnings

# ... (keep the rest of the imports and function definitions as they were)

def perform_statistical_tests(results):
    classifier_names = list(results.keys())
    data = [results[name] for name in classifier_names]

    print("Summary Statistics:")
    summary = pd.DataFrame({name: results[name] for name in classifier_names}).describe()
    print(summary)
    print()

    if len(set(map(tuple, data))) == 1:
        print("All classifiers performed identically on this dataset.")
        return

    print("1. ANOVA Test")
    try:
        with warnings.catch_warnings():
            warnings.filterwarnings('ignore', category=stats.ConstantInputWarning)
            f_statistic, p_value = stats.f_oneway(*data)
        print(f"F-statistic: {f_statistic}")
        print(f"p-value: {p_value}")
    except ValueError as e:
        print(f"ANOVA test could not be performed: {str(e)}")

    print("\n2. Paired t-tests")
    t_test_results = []
    for i, clf1 in enumerate(classifier_names):
        for clf2 in classifier_names[i+1:]:
            if np.array_equal(results[clf1], results[clf2]):
                print(f"{clf1} vs {clf2}: Identical performance, skipping test")
            else:
                t_statistic, p_value = ttest_rel(results[clf1], results[clf2])
                t_test_results.append((clf1, clf2, t_statistic, p_value))

    if t_test_results:
        _, p_values_corrected, _, _ = multipletests([r[3] for r in t_test_results], method='bonferroni')

        for (clf1, clf2, t_statistic, p_value), p_corrected in zip(t_test_results, p_values_corrected):
            print(f"{clf1} vs {clf2}:")
            print(f"  t-statistic: {t_statistic}")
            print(f"  p-value: {p_value}")
            print(f"  Bonferroni-corrected p-value: {p_corrected}")
            print(f"  Significant: {'Yes' if p_corrected < 0.05 else 'No'}")
            print()

    print("\n3. Kruskal-Wallis Test")
    try:
        h_statistic, kw_p_value = kruskal(*data)
        print(f"H-statistic: {h_statistic}")
        print(f"p-value: {kw_p_value}")
    except ValueError as e:
        print(f"Kruskal-Wallis test could not be performed: {str(e)}")

    print("\n4. Wilcoxon Signed-Rank Tests / Mann-Whitney U-tests")
    wilcoxon_results = []
    for i, clf1 in enumerate(classifier_names):
        for clf2 in classifier_names[i+1:]:
            if np.array_equal(results[clf1], results[clf2]):
                print(f"{clf1} vs {clf2}: Identical performance, skipping test")
                wilcoxon_results.append((clf1, clf2, None, 1.0))
            else:
                try:
                    statistic, p_value = wilcoxon(results[clf1], results[clf2], zero_method='zsplit')
                except ValueError:
                    statistic, p_value = ranksums(results[clf1], results[clf2])
                wilcoxon_results.append((clf1, clf2, statistic, p_value))

    if wilcoxon_results:
        _, p_values_corrected, _, _ = multipletests([r[3] for r in wilcoxon_results], method='bonferroni')

        for (clf1, clf2, statistic, p_value), p_corrected in zip(wilcoxon_results, p_values_corrected):
            print(f"{clf1} vs {clf2}:")
            if statistic is not None:
                print(f"  Statistic: {statistic}")
                print(f"  p-value: {p_value}")
                print(f"  Bonferroni-corrected p-value: {p_corrected}")
                print(f"  Significant: {'Yes' if p_corrected < 0.05 else 'No'}")
            else:
                print("  No significant difference (identical performance)")
            print()

    print("\n5. Friedman Test")
    try:
        friedman_statistic, fr_p_value = friedmanchisquare(*data)
        print(f"Chi-square statistic: {friedman_statistic}")
        print(f"p-value: {fr_p_value}")
    except ValueError as e:
        print(f"Friedman test could not be performed: {str(e)}")

# ... (keep the rest of the code as it was)

# Main execution
all_results = {}
datasets = create_datasets()

for dataset_name, (X, y) in datasets:
    print(f"Processing dataset: {dataset_name}")
    results = evaluate_classifiers(X, y, classifiers)
    all_results[dataset_name] = results
    visualize_results(results, dataset_name)
    perform_statistical_tests(results)
    print("\n" + "="*50 + "\n")

# Create and print the algorithm vs algorithm comparison table
comparison_table = create_comparison_table(all_results)
print("\nAlgorithm vs Algorithm Comparison Table:")
print(comparison_table)
# Out:
# Processing dataset: Linear
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Summary Statistics:
#        Naive Bayes  Decision Tree  Random Forest  Gradient Boosting  AdaBoost  \
# count     5.000000       5.000000       5.000000           5.000000  5.000000
# mean      0.835000       0.855000       0.894000           0.903000  0.881000
# std       0.016956       0.030208       0.026315           0.021679  0.026077
# min       0.815000       0.815000       0.855000           0.875000  0.840000
# 25%       0.825000       0.850000       0.890000           0.895000  0.875000
# 50%       0.830000       0.855000       0.890000           0.905000  0.890000
# 75%       0.850000       0.855000       0.910000           0.905000  0.890000
# max       0.855000       0.900000       0.925000           0.935000  0.910000
#
#        K-Nearest Neighbors       SVM       MLP  Logistic Regression       LDA  \
# count             5.000000  5.000000  5.000000             5.000000  5.000000
# mean              0.783000  0.862000  0.838000             0.867000  0.867000
# std               0.019558  0.025397  0.026833             0.028853  0.036503
# min               0.765000  0.825000  0.800000             0.830000  0.825000
# 25%               0.770000  0.850000  0.835000             0.845000  0.840000
# 50%               0.780000  0.865000  0.835000             0.875000  0.865000
# 75%               0.785000  0.885000  0.845000             0.885000  0.890000
# max               0.815000  0.885000  0.875000             0.900000  0.915000
#
#             QDA  Gaussian Process   XGBoost
# count  5.000000          5.000000  5.000000
# mean   0.707000          0.822000  0.871000
# std    0.052868          0.015652  0.021909
# min    0.650000          0.805000  0.840000
# 25%    0.650000          0.815000  0.865000
# 50%    0.735000          0.815000  0.870000
# 75%    0.740000          0.830000  0.880000
# max    0.760000          0.845000  0.900000
#
# 1. ANOVA Test
# F-statistic: 16.88862370723944
# p-value: 6.548175611598132e-14
#
# 2. Paired t-tests
# Naive Bayes vs Decision Tree:
#   t-statistic: -1.6754156331667822
#   p-value: 0.1691624429584955
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Random Forest:
#   t-statistic: -10.19364742186005
#   p-value: 0.0005217600264269947
#   Bonferroni-corrected p-value: 0.04069728206130559
#   Significant: Yes
#
# Naive Bayes vs Gradient Boosting:
#   t-statistic: -11.255440084992204
#   p-value: 0.00035496522917500954
#   Bonferroni-corrected p-value: 0.027687287875650744
#   Significant: Yes
#
# Naive Bayes vs AdaBoost:
#   t-statistic: -7.413571269033499
#   p-value: 0.0017665112521115527
#   Bonferroni-corrected p-value: 0.1377878776647011
#   Significant: No
#
# Naive Bayes vs K-Nearest Neighbors:
#   t-statistic: 6.0448772146786
#   p-value: 0.0037778691848258735
#   Bonferroni-corrected p-value: 0.2946737964164181
#   Significant: No
#
# Naive Bayes vs SVM:
#   t-statistic: -5.0137741307804005
#   p-value: 0.007417872381932223
#   Bonferroni-corrected p-value: 0.5785940457907134
#   Significant: No
#
# Naive Bayes vs MLP:
#   t-statistic: -0.49656353316142576
#   p-value: 0.6455470832456037
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Logistic Regression:
#   t-statistic: -3.4914862437758782
#   p-value: 0.025089001332627554
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs LDA:
#   t-statistic: -2.8174429002419963
#   p-value: 0.04795257121573951
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs QDA:
#   t-statistic: 5.219058367278909
#   p-value: 0.006431611494073596
#   Bonferroni-corrected p-value: 0.5016656965377405
#   Significant: No
#
# Naive Bayes vs Gaussian Process:
#   t-statistic: 6.499999999999962
#   p-value: 0.0028900071171007995
#   Bonferroni-corrected p-value: 0.22542055513386236
#   Significant: No
#
# Naive Bayes vs XGBoost:
#   t-statistic: -5.041008302500836
#   p-value: 0.007276908700114902
#   Bonferroni-corrected p-value: 0.5675988786089624
#   Significant: No
#
# Decision Tree vs Random Forest:
#   t-statistic: -2.9608395102043814
#   p-value: 0.04151982026776364
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gradient Boosting:
#   t-statistic: -4.764400003060465
#   p-value: 0.00887647236833735
#   Bonferroni-corrected p-value: 0.6923648447303133
#   Significant: No
#
# Decision Tree vs AdaBoost:
#   t-statistic: -1.5867233140131187
#   p-value: 0.18776361636295175
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs K-Nearest Neighbors:
#   t-statistic: 7.329407019253728
#   p-value: 0.0018442262503028867
#   Bonferroni-corrected p-value: 0.14384964752362517
#   Significant: No
#
# Decision Tree vs SVM:
#   t-statistic: -0.46006854593054247
#   p-value: 0.669364103343178
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs MLP:
#   t-statistic: 0.9790508823255409
#   p-value: 0.38298941258896296
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Logistic Regression:
#   t-statistic: -0.7721873425053442
#   p-value: 0.48309283312218987
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs LDA:
#   t-statistic: -0.780307306514826
#   p-value: 0.47880471626214116
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs QDA:
#   t-statistic: 4.230298433515216
#   p-value: 0.013366861076649564
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gaussian Process:
#   t-statistic: 2.4665358060813882
#   p-value: 0.06920369636414934
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs XGBoost:
#   t-statistic: -0.847998304005088
#   p-value: 0.4442016727397878
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gradient Boosting:
#   t-statistic: -2.092457497388747
#   p-value: 0.10453999977837539
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs AdaBoost:
#   t-statistic: 2.0179913668364655
#   p-value: 0.1137578048286257
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs K-Nearest Neighbors:
#   t-statistic: 13.663155498705924
#   p-value: 0.0001661862105850192
#   Bonferroni-corrected p-value: 0.012962524425631498
#   Significant: Yes
#
# Random Forest vs SVM:
#   t-statistic: 9.436285193913417
#   p-value: 0.0007032528094098962
#   Bonferroni-corrected p-value: 0.054853719133971905
#   Significant: No
#
# Random Forest vs MLP:
#   t-statistic: 7.841568470556851
#   p-value: 0.001428440256110888
#   Bonferroni-corrected p-value: 0.11141833997664925
#   Significant: No
#
# Random Forest vs Logistic Regression:
#   t-statistic: 3.086974532565159
#   p-value: 0.03668198940044108
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs LDA:
#   t-statistic: 2.748527632220153
#   p-value: 0.05145223064196388
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs QDA:
#   t-statistic: 7.383176933867208
#   p-value: 0.0017941012681702664
#   Bonferroni-corrected p-value: 0.13993989891728079
#   Significant: No
#
# Random Forest vs Gaussian Process:
#   t-statistic: 9.797958971132687
#   p-value: 0.0006081849444633421
#   Bonferroni-corrected p-value: 0.04743842566814068
#   Significant: Yes
#
# Random Forest vs XGBoost:
#   t-statistic: 2.4379951240146283
#   p-value: 0.0713625486623809
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs AdaBoost:
#   t-statistic: 2.557448052364024
#   p-value: 0.06280761100070116
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs K-Nearest Neighbors:
#   t-statistic: 28.685486624025426
#   p-value: 8.790062111109615e-06
#   Bonferroni-corrected p-value: 0.0006856248446665499
#   Significant: Yes
#
# Gradient Boosting vs SVM:
#   t-statistic: 6.045120202350782
#   p-value: 0.0037773119576249023
#   Bonferroni-corrected p-value: 0.29463033269474237
#   Significant: No
#
# Gradient Boosting vs MLP:
#   t-statistic: 6.500000000000001
#   p-value: 0.0028900071171007345
#   Bonferroni-corrected p-value: 0.22542055513385728
#   Significant: No
#
# Gradient Boosting vs Logistic Regression:
#   t-statistic: 3.538606947717531
#   p-value: 0.024043528799373774
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs LDA:
#   t-statistic: 3.1157447213369913
#   p-value: 0.035673066656769746
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs QDA:
#   t-statistic: 7.376557309050819
#   p-value: 0.0018001805555264137
#   Bonferroni-corrected p-value: 0.14041408333106026
#   Significant: No
#
# Gradient Boosting vs Gaussian Process:
#   t-statistic: 10.37098727456456
#   p-value: 0.0004880008221521771
#   Bonferroni-corrected p-value: 0.038064064127869814
#   Significant: Yes
#
# Gradient Boosting vs XGBoost:
#   t-statistic: 2.8736848324283986
#   p-value: 0.045300143954446065
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs K-Nearest Neighbors:
#   t-statistic: 8.166666666666666
#   p-value: 0.0012239432059442175
#   Bonferroni-corrected p-value: 0.09546757006364896
#   Significant: No
#
# AdaBoost vs SVM:
#   t-statistic: 3.062127263296445
#   p-value: 0.0375803886130333
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs MLP:
#   t-statistic: 12.680008229321128
#   p-value: 0.00022278031862272478
#   Bonferroni-corrected p-value: 0.017376864852572532
#   Significant: Yes
#
# AdaBoost vs Logistic Regression:
#   t-statistic: 1.0785197020798836
#   p-value: 0.34149901815031863
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs LDA:
#   t-statistic: 0.9471141280884336
#   p-value: 0.39721057947658195
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs QDA:
#   t-statistic: 8.35708265184849
#   p-value: 0.001120917402064984
#   Bonferroni-corrected p-value: 0.08743155736106877
#   Significant: No
#
# AdaBoost vs Gaussian Process:
#   t-statistic: 8.94555691423103
#   p-value: 0.0008637343026593513
#   Bonferroni-corrected p-value: 0.06737127560742939
#   Significant: No
#
# AdaBoost vs XGBoost:
#   t-statistic: 1.7541160386140586
#   p-value: 0.15427287107931656
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs SVM:
#   t-statistic: -7.959925005386074
#   p-value: 0.0013494209257172223
#   Bonferroni-corrected p-value: 0.10525483220594334
#   Significant: No
#
# K-Nearest Neighbors vs MLP:
#   t-statistic: -4.128226437724409
#   p-value: 0.014514841214414077
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs Logistic Regression:
#   t-statistic: -7.339114075952711
#   p-value: 0.0018350504912543854
#   Bonferroni-corrected p-value: 0.14313393831784207
#   Significant: No
#
# K-Nearest Neighbors vs LDA:
#   t-statistic: -6.287241983946996
#   p-value: 0.003268880982662055
#   Bonferroni-corrected p-value: 0.2549727166476403
#   Significant: No
#
# K-Nearest Neighbors vs QDA:
#   t-statistic: 2.754997847658774
#   p-value: 0.051111358508252394
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs Gaussian Process:
#   t-statistic: -3.929583230507049
#   p-value: 0.017109011241689096
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs XGBoost:
#   t-statistic: -6.623847379555838
#   p-value: 0.0026942784868536135
#   Bonferroni-corrected p-value: 0.21015372197458185
#   Significant: No
#
# SVM vs MLP:
#   t-statistic: 4.495611895592128
#   p-value: 0.010858991726469413
#   Bonferroni-corrected p-value: 0.8470013546646141
#   Significant: No
#
# SVM vs Logistic Regression:
#   t-statistic: -0.7071067811865476
#   p-value: 0.5185185185185184
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs LDA:
#   t-statistic: -0.5504818825631803
#   p-value: 0.6112854308932067
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs QDA:
#   t-statistic: 6.506519942497258
#   p-value: 0.0028792750978921264
#   Bonferroni-corrected p-value: 0.22458345763558585
#   Significant: No
#
# SVM vs Gaussian Process:
#   t-statistic: 6.531972647421785
#   p-value: 0.002837845926734487
#   Bonferroni-corrected p-value: 0.22135198228529
#   Significant: No
#
# SVM vs XGBoost:
#   t-statistic: -1.230454668644394
#   p-value: 0.2859386304278619
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs Logistic Regression:
#   t-statistic: -2.558270330069139
#   p-value: 0.06275292754410743
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs LDA:
#   t-statistic: -2.1859572481887852
#   p-value: 0.09411597066730647
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs QDA:
#   t-statistic: 6.185717356913501
#   p-value: 0.0034711436206750477
#   Bonferroni-corrected p-value: 0.2707492024126537
#   Significant: No
#
# MLP vs Gaussian Process:
#   t-statistic: 2.7643789618603525
#   p-value: 0.050621762549260214
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs XGBoost:
#   t-statistic: -7.116963031426944
#   p-value: 0.0020600054014682833
#   Bonferroni-corrected p-value: 0.1606804213145261
#   Significant: No
#
# Logistic Regression vs LDA:
#   t-statistic: 0.0
#   p-value: 1.0
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Logistic Regression vs QDA:
#   t-statistic: 5.595979334261351
#   p-value: 0.0050051424871473335
#   Bonferroni-corrected p-value: 0.390401113997492
#   Significant: No
#
# Logistic Regression vs Gaussian Process:
#   t-statistic: 4.7434164902525655
#   p-value: 0.00901448133390896
#   Bonferroni-corrected p-value: 0.7031295440448989
#   Significant: No
#
# Logistic Regression vs XGBoost:
#   t-statistic: -0.3255153835084638
#   p-value: 0.7611070254038373
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs QDA:
#   t-statistic: 4.985415622798045
#   p-value: 0.007568208709551246
#   Bonferroni-corrected p-value: 0.5903202793449972
#   Significant: No
#
# LDA vs Gaussian Process:
#   t-statistic: 3.7052413631667793
#   p-value: 0.020740117727804666
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs XGBoost:
#   t-statistic: -0.2590095632952705
#   p-value: 0.8084108454121025
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# QDA vs Gaussian Process:
#   t-statistic: -4.892509742832443
#   p-value: 0.008087427819204122
#   Bonferroni-corrected p-value: 0.6308193698979215
#   Significant: No
#
# QDA vs XGBoost:
#   t-statistic: -9.189441760760626
#   p-value: 0.0007788678598924625
#   Bonferroni-corrected p-value: 0.06075169307161207
#   Significant: No
#
# Gaussian Process vs XGBoost:
#   t-statistic: -8.166666666666645
#   p-value: 0.0012239432059442295
#   Bonferroni-corrected p-value: 0.09546757006364989
#   Significant: No
#
#
# 3. Kruskal-Wallis Test
# H-statistic: 44.564540995094596
# p-value: 1.2233770529491264e-05
#
# 4. Wilcoxon Signed-Rank Tests / Mann-Whitney U-tests
# Naive Bayes vs Decision Tree:
#   Statistic: 3.0
#   p-value: 0.3125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Random Forest:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Gradient Boosting:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs AdaBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs MLP:
#   Statistic: 5.5
#   p-value: 0.625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Logistic Regression:
#   Statistic: 0.5
#   p-value: 0.05675944638601352
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs LDA:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Random Forest:
#   Statistic: 0.5
#   p-value: 0.05905822909053671
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gradient Boosting:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs AdaBoost:
#   Statistic: 3.0
#   p-value: 0.3125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs SVM:
#   Statistic: 6.0
#   p-value: 0.8125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs MLP:
#   Statistic: 4.5
#   p-value: 0.625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Logistic Regression:
#   Statistic: 5.5
#   p-value: 0.5896385516265671
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs LDA:
#   Statistic: 4.5
#   p-value: 0.4375
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gaussian Process:
#   Statistic: 0.5
#   p-value: 0.05905822909053671
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs XGBoost:
#   Statistic: 4.5
#   p-value: 0.4375
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gradient Boosting:
#   Statistic: 1.5
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs AdaBoost:
#   Statistic: 1.5
#   p-value: 0.10247043485974937
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Logistic Regression:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs LDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs AdaBoost:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Logistic Regression:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs LDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs Logistic Regression:
#   Statistic: 5.5
#   p-value: 0.5896385516265671
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs LDA:
#   Statistic: 4.5
#   p-value: 0.41849223344681985
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs XGBoost:
#   Statistic: 2.5
#   p-value: 0.17752985241215347
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs Logistic Regression:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs LDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
#   Significant: No
#
# K-Nearest Neighbors vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs Logistic Regression:
#   Statistic: 5.0
#   p-value: 0.4982248534183389
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs LDA:
#   Statistic: 4.5
#   p-value: 0.41849223344681985
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs XGBoost:
#   Statistic: 4.5
#   p-value: 0.4375
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs Logistic Regression:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs LDA:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs Gaussian Process:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Logistic Regression vs LDA:
#   Statistic: 7.0
#   p-value: 1.0
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Logistic Regression vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Logistic Regression vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Logistic Regression vs XGBoost:
#   Statistic: 5.5
#   p-value: 0.625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs XGBoost:
#   Statistic: 5.5
#   p-value: 0.5896385516265671
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# QDA vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# QDA vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gaussian Process vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
#
# 5. Friedman Test
# Chi-square statistic: 50.596568898727156
# p-value: 1.097229147551322e-06
#
# ==================================================
#
# Processing dataset: Nonlinear
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Summary Statistics:
#        Naive Bayes  Decision Tree  Random Forest  Gradient Boosting  AdaBoost  \
# count     5.000000       5.000000       5.000000           5.000000  5.000000
# mean      0.835000       0.854000       0.896000           0.903000  0.881000
# std       0.016956       0.022192       0.031898           0.021679  0.026077
# min       0.815000       0.820000       0.845000           0.875000  0.840000
# 25%       0.825000       0.850000       0.890000           0.895000  0.875000
# 50%       0.830000       0.855000       0.905000           0.905000  0.890000
# 75%       0.850000       0.865000       0.910000           0.905000  0.890000
# max       0.855000       0.880000       0.930000           0.935000  0.910000
#
#        K-Nearest Neighbors       SVM       MLP  Logistic Regression       LDA  \
# count             5.000000  5.000000  5.000000             5.000000  5.000000
# mean              0.783000  0.862000  0.827000             0.867000  0.867000
# std               0.019558  0.025397  0.027295             0.028853  0.036503
# min               0.765000  0.825000  0.790000             0.830000  0.825000
# 25%               0.770000  0.850000  0.810000             0.845000  0.840000
# 50%               0.780000  0.865000  0.830000             0.875000  0.865000
# 75%               0.785000  0.885000  0.850000             0.885000  0.890000
# max               0.815000  0.885000  0.855000             0.900000  0.915000
#
#             QDA  Gaussian Process   XGBoost
# count  5.000000          5.000000  5.000000
# mean   0.707000          0.822000  0.871000
# std    0.052868          0.015652  0.021909
# min    0.650000          0.805000  0.840000
# 25%    0.650000          0.815000  0.865000
# 50%    0.735000          0.815000  0.870000
# 75%    0.740000          0.830000  0.880000
# max    0.760000          0.845000  0.900000
#
# 1. ANOVA Test
# F-statistic: 17.235623898766626
# p-value: 4.3802890226647876e-14
#
# 2. Paired t-tests
# Naive Bayes vs Decision Tree:
#   t-statistic: -1.783428366962942
#   p-value: 0.14908749359680012
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Random Forest:
#   t-statistic: -6.577799165409744
#   p-value: 0.002765088254797146
#   Bonferroni-corrected p-value: 0.21567688387417738
#   Significant: No
#
# Naive Bayes vs Gradient Boosting:
#   t-statistic: -11.255440084992204
#   p-value: 0.00035496522917500954
#   Bonferroni-corrected p-value: 0.027687287875650744
#   Significant: Yes
#
# Naive Bayes vs AdaBoost:
#   t-statistic: -7.413571269033499
#   p-value: 0.0017665112521115527
#   Bonferroni-corrected p-value: 0.1377878776647011
#   Significant: No
#
# Naive Bayes vs K-Nearest Neighbors:
#   t-statistic: 6.0448772146786
#   p-value: 0.0037778691848258735
#   Bonferroni-corrected p-value: 0.2946737964164181
#   Significant: No
#
# Naive Bayes vs SVM:
#   t-statistic: -5.0137741307804005
#   p-value: 0.007417872381932223
#   Bonferroni-corrected p-value: 0.5785940457907134
#   Significant: No
#
# Naive Bayes vs MLP:
#   t-statistic: 0.8601653289127492
#   p-value: 0.4381986781983326
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Logistic Regression:
#   t-statistic: -3.4914862437758782
#   p-value: 0.025089001332627554
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs LDA:
#   t-statistic: -2.8174429002419963
#   p-value: 0.04795257121573951
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs QDA:
#   t-statistic: 5.219058367278909
#   p-value: 0.006431611494073596
#   Bonferroni-corrected p-value: 0.5016656965377405
#   Significant: No
#
# Naive Bayes vs Gaussian Process:
#   t-statistic: 6.499999999999962
#   p-value: 0.0028900071171007995
#   Bonferroni-corrected p-value: 0.22542055513386236
#   Significant: No
#
# Naive Bayes vs XGBoost:
#   t-statistic: -5.041008302500836
#   p-value: 0.007276908700114902
#   Bonferroni-corrected p-value: 0.5675988786089624
#   Significant: No
#
# Decision Tree vs Random Forest:
#   t-statistic: -2.3990210075056675
#   p-value: 0.0744353271110326
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gradient Boosting:
#   t-statistic: -4.5993678937465345
#   p-value: 0.010035672315367688
#   Bonferroni-corrected p-value: 0.7827824405986796
#   Significant: No
#
# Decision Tree vs AdaBoost:
#   t-statistic: -1.7197103393059014
#   p-value: 0.1606044806348146
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs K-Nearest Neighbors:
#   t-statistic: 7.246407155733563
#   p-value: 0.0019250427630495062
#   Bonferroni-corrected p-value: 0.15015333551786147
#   Significant: No
#
# Decision Tree vs SVM:
#   t-statistic: -0.5286548803640718
#   p-value: 0.62501857123677
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs MLP:
#   t-statistic: 1.4008265201068693
#   p-value: 0.2338719946906985
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Logistic Regression:
#   t-statistic: -0.8365362877141229
#   p-value: 0.44991718523653434
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs LDA:
#   t-statistic: -0.7818002131215428
#   p-value: 0.47801951502993534
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs QDA:
#   t-statistic: 4.522541742701969
#   p-value: 0.010637670136093189
#   Bonferroni-corrected p-value: 0.8297382706152687
#   Significant: No
#
# Decision Tree vs Gaussian Process:
#   t-statistic: 2.7905326092604645
#   p-value: 0.04928524283315447
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs XGBoost:
#   t-statistic: -1.004353525154565
#   p-value: 0.37203595505341985
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gradient Boosting:
#   t-statistic: -0.9754262200082646
#   p-value: 0.38458114766298657
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs AdaBoost:
#   t-statistic: 1.7928429140015905
#   p-value: 0.14746168454146463
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs K-Nearest Neighbors:
#   t-statistic: 11.216191673871503
#   p-value: 0.0003598309689532891
#   Bonferroni-corrected p-value: 0.02806681557835655
#   Significant: Yes
#
# Random Forest vs SVM:
#   t-statistic: 7.013664474559795
#   p-value: 0.0021761652235400713
#   Bonferroni-corrected p-value: 0.16974088743612556
#   Significant: No
#
# Random Forest vs MLP:
#   t-statistic: 7.551024041271236
#   p-value: 0.0016480926889494516
#   Bonferroni-corrected p-value: 0.12855122973805722
#   Significant: No
#
# Random Forest vs Logistic Regression:
#   t-statistic: 3.040026026493563
#   p-value: 0.03840125333384681
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs LDA:
#   t-statistic: 2.722074875890806
#   p-value: 0.05287347897451591
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs QDA:
#   t-statistic: 7.725555677510569
#   p-value: 0.0015115233091677325
#   Bonferroni-corrected p-value: 0.11789881811508314
#   Significant: No
#
# Random Forest vs Gaussian Process:
#   t-statistic: 7.104227338912311
#   p-value: 0.0020739061490513975
#   Bonferroni-corrected p-value: 0.161764679626009
#   Significant: No
#
# Random Forest vs XGBoost:
#   t-statistic: 2.3570226039551585
#   p-value: 0.07791562124471589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs AdaBoost:
#   t-statistic: 2.557448052364024
#   p-value: 0.06280761100070116
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs K-Nearest Neighbors:
#   t-statistic: 28.685486624025426
#   p-value: 8.790062111109615e-06
#   Bonferroni-corrected p-value: 0.0006856248446665499
#   Significant: Yes
#
# Gradient Boosting vs SVM:
#   t-statistic: 6.045120202350782
#   p-value: 0.0037773119576249023
#   Bonferroni-corrected p-value: 0.29463033269474237
#   Significant: No
#
# Gradient Boosting vs MLP:
#   t-statistic: 6.289804753377999
#   p-value: 0.003263965547252931
#   Bonferroni-corrected p-value: 0.2545893126857286
#   Significant: No
#
# Gradient Boosting vs Logistic Regression:
#   t-statistic: 3.538606947717531
#   p-value: 0.024043528799373774
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs LDA:
#   t-statistic: 3.1157447213369913
#   p-value: 0.035673066656769746
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs QDA:
#   t-statistic: 7.376557309050819
#   p-value: 0.0018001805555264137
#   Bonferroni-corrected p-value: 0.14041408333106026
#   Significant: No
#
# Gradient Boosting vs Gaussian Process:
#   t-statistic: 10.37098727456456
#   p-value: 0.0004880008221521771
#   Bonferroni-corrected p-value: 0.038064064127869814
#   Significant: Yes
#
# Gradient Boosting vs XGBoost:
#   t-statistic: 2.8736848324283986
#   p-value: 0.045300143954446065
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs K-Nearest Neighbors:
#   t-statistic: 8.166666666666666
#   p-value: 0.0012239432059442175
#   Bonferroni-corrected p-value: 0.09546757006364896
#   Significant: No
#
# AdaBoost vs SVM:
#   t-statistic: 3.062127263296445
#   p-value: 0.0375803886130333
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs MLP:
#   t-statistic: 6.094792598217489
#   p-value: 0.0036654905708896415
#   Bonferroni-corrected p-value: 0.28590826452939205
#   Significant: No
#
# AdaBoost vs Logistic Regression:
#   t-statistic: 1.0785197020798836
#   p-value: 0.34149901815031863
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs LDA:
#   t-statistic: 0.9471141280884336
#   p-value: 0.39721057947658195
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs QDA:
#   t-statistic: 8.35708265184849
#   p-value: 0.001120917402064984
#   Bonferroni-corrected p-value: 0.08743155736106877
#   Significant: No
#
# AdaBoost vs Gaussian Process:
#   t-statistic: 8.94555691423103
#   p-value: 0.0008637343026593513
#   Bonferroni-corrected p-value: 0.06737127560742939
#   Significant: No
#
# AdaBoost vs XGBoost:
#   t-statistic: 1.7541160386140586
#   p-value: 0.15427287107931656
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs SVM:
#   t-statistic: -7.959925005386074
#   p-value: 0.0013494209257172223
#   Bonferroni-corrected p-value: 0.10525483220594334
#   Significant: No
#
# K-Nearest Neighbors vs MLP:
#   t-statistic: -3.142857142857146
#   p-value: 0.03475200374179457
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs Logistic Regression:
#   t-statistic: -7.339114075952711
#   p-value: 0.0018350504912543854
#   Bonferroni-corrected p-value: 0.14313393831784207
#   Significant: No
#
# K-Nearest Neighbors vs LDA:
#   t-statistic: -6.287241983946996
#   p-value: 0.003268880982662055
#   Bonferroni-corrected p-value: 0.2549727166476403
#   Significant: No
#
# K-Nearest Neighbors vs QDA:
#   t-statistic: 2.754997847658774
#   p-value: 0.051111358508252394
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs Gaussian Process:
#   t-statistic: -3.929583230507049
#   p-value: 0.017109011241689096
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs XGBoost:
#   t-statistic: -6.623847379555838
#   p-value: 0.0026942784868536135
#   Bonferroni-corrected p-value: 0.21015372197458185
#   Significant: No
#
# SVM vs MLP:
#   t-statistic: 5.368754921931591
#   p-value: 0.00581215681841241
#   Bonferroni-corrected p-value: 0.45334823183616796
#   Significant: No
#
# SVM vs Logistic Regression:
#   t-statistic: -0.7071067811865476
#   p-value: 0.5185185185185184
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs LDA:
#   t-statistic: -0.5504818825631803
#   p-value: 0.6112854308932067
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# SVM vs QDA:
#   t-statistic: 6.506519942497258
#   p-value: 0.0028792750978921264
#   Bonferroni-corrected p-value: 0.22458345763558585
#   Significant: No
#
# SVM vs Gaussian Process:
#   t-statistic: 6.531972647421785
#   p-value: 0.002837845926734487
#   Bonferroni-corrected p-value: 0.22135198228529
#   Significant: No
#
# SVM vs XGBoost:
#   t-statistic: -1.230454668644394
#   p-value: 0.2859386304278619
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs Logistic Regression:
#   t-statistic: -4.159001959280285
#   p-value: 0.014156615205215838
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs LDA:
#   t-statistic: -3.067859955389477
#   p-value: 0.03737084234715611
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs QDA:
#   t-statistic: 6.238502938920441
#   p-value: 0.0033641196367149785
#   Bonferroni-corrected p-value: 0.26240133166376833
#   Significant: No
#
# MLP vs Gaussian Process:
#   t-statistic: 0.5872202195147066
#   p-value: 0.5886021617194503
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# MLP vs XGBoost:
#   t-statistic: -8.241955141918934
#   p-value: 0.0011818615271342848
#   Bonferroni-corrected p-value: 0.09218519911647421
#   Significant: No
#
# Logistic Regression vs LDA:
#   t-statistic: 0.0
#   p-value: 1.0
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Logistic Regression vs QDA:
#   t-statistic: 5.595979334261351
#   p-value: 0.0050051424871473335
#   Bonferroni-corrected p-value: 0.390401113997492
#   Significant: No
#
# Logistic Regression vs Gaussian Process:
#   t-statistic: 4.7434164902525655
#   p-value: 0.00901448133390896
#   Bonferroni-corrected p-value: 0.7031295440448989
#   Significant: No
#
# Logistic Regression vs XGBoost:
#   t-statistic: -0.3255153835084638
#   p-value: 0.7611070254038373
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs QDA:
#   t-statistic: 4.985415622798045
#   p-value: 0.007568208709551246
#   Bonferroni-corrected p-value: 0.5903202793449972
#   Significant: No
#
# LDA vs Gaussian Process:
#   t-statistic: 3.7052413631667793
#   p-value: 0.020740117727804666
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# LDA vs XGBoost:
#   t-statistic: -0.2590095632952705
#   p-value: 0.8084108454121025
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# QDA vs Gaussian Process:
#   t-statistic: -4.892509742832443
#   p-value: 0.008087427819204122
#   Bonferroni-corrected p-value: 0.6308193698979215
#   Significant: No
#
# QDA vs XGBoost:
#   t-statistic: -9.189441760760626
#   p-value: 0.0007788678598924625
#   Bonferroni-corrected p-value: 0.06075169307161207
#   Significant: No
#
# Gaussian Process vs XGBoost:
#   t-statistic: -8.166666666666645
#   p-value: 0.0012239432059442295
#   Bonferroni-corrected p-value: 0.09546757006364989
#   Significant: No
#
#
# 3. Kruskal-Wallis Test
# H-statistic: 45.38398353693244
# p-value: 8.855099579518668e-06
#
# 4. Wilcoxon Signed-Rank Tests / Mann-Whitney U-tests
# Naive Bayes vs Decision Tree:
#   Statistic: 3.0
#   p-value: 0.3125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Random Forest:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Gradient Boosting:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs AdaBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs MLP:
#   Statistic: 5.5
#   p-value: 0.5896385516265671
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Logistic Regression:
#   Statistic: 0.5
#   p-value: 0.05675944638601352
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs LDA:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Random Forest:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gradient Boosting:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs AdaBoost:
#   Statistic: 2.0
#   p-value: 0.1875
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs SVM:
#   Statistic: 5.5
#   p-value: 0.625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs MLP:
#   Statistic: 3.0
#   p-value: 0.3125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Logistic Regression:
#   Statistic: 4.5
#   p-value: 0.4375
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs LDA:
#   Statistic: 3.0
#   p-value: 0.3125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs XGBoost:
#   Statistic: 4.5
#   p-value: 0.4375
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gradient Boosting:
#   Statistic: 4.5
#   p-value: 0.4375
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs AdaBoost:
#   Statistic: 1.5
#   p-value: 0.10405923452892792
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Logistic Regression:
#   Statistic: 0.5
#   p-value: 0.05790726541729728
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs LDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs AdaBoost:
#   Statistic: 1.0
#   p-value: 0.125
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs K-Nearest Neighbors:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs SVM:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs MLP:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Logistic Regression:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs LDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs QDA:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Gaussian Process:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs XGBoost:
#   Statistic: 0.0
#   p-value: 0.0625
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# ...
#
# Decision Tree vs Random Forest:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gradient Boosting:
#   t-statistic: 0.5897678246195884
#   p-value: 0.5870496397870563
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs K-Nearest Neighbors:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs SVM:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs MLP:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Logistic Regression:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs LDA:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs QDA:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gaussian Process:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs XGBoost:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gradient Boosting:
#   t-statistic: 1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs AdaBoost:
#   t-statistic: 1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs AdaBoost:
#   t-statistic: -0.5897678246195884
#   p-value: 0.5870496397870563
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs K-Nearest Neighbors:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs SVM:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs MLP:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Logistic Regression:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs LDA:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs QDA:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Gaussian Process:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs XGBoost:
#   t-statistic: -1.0000000000000002
#   p-value: 0.3739009663000589
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs K-Nearest Neighbors:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs SVM:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs MLP:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs Logistic Regression:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs LDA:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs QDA:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs Gaussian Process:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs XGBoost:
#   t-statistic: -1.0
#   p-value: 0.373900966300059
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
#
# 3. Kruskal-Wallis Test
# H-statistic: 10.323809523809517
# p-value: 0.5875760620124757
#
# 4. Wilcoxon Signed-Rank Tests / Mann-Whitney U-tests
# Naive Bayes vs Random Forest: Identical performance, skipping test
# Naive Bayes vs K-Nearest Neighbors: Identical performance, skipping test
# Naive Bayes vs SVM: Identical performance, skipping test
# Naive Bayes vs MLP: Identical performance, skipping test
# Naive Bayes vs Logistic Regression: Identical performance, skipping test
# Naive Bayes vs LDA: Identical performance, skipping test
# Naive Bayes vs QDA: Identical performance, skipping test
# Naive Bayes vs Gaussian Process: Identical performance, skipping test
# Naive Bayes vs XGBoost: Identical performance, skipping test
# Decision Tree vs AdaBoost: Identical performance, skipping test
# Random Forest vs K-Nearest Neighbors: Identical performance, skipping test
# Random Forest vs SVM: Identical performance, skipping test
# Random Forest vs MLP: Identical performance, skipping test
# Random Forest vs Logistic Regression: Identical performance, skipping test
# Random Forest vs LDA: Identical performance, skipping test
# Random Forest vs QDA: Identical performance, skipping test
# Random Forest vs Gaussian Process: Identical performance, skipping test
# Random Forest vs XGBoost: Identical performance, skipping test
# K-Nearest Neighbors vs SVM: Identical performance, skipping test
# K-Nearest Neighbors vs MLP: Identical performance, skipping test
# K-Nearest Neighbors vs Logistic Regression: Identical performance, skipping test
# K-Nearest Neighbors vs LDA: Identical performance, skipping test
# K-Nearest Neighbors vs QDA: Identical performance, skipping test
# K-Nearest Neighbors vs Gaussian Process: Identical performance, skipping test
# K-Nearest Neighbors vs XGBoost: Identical performance, skipping test
# SVM vs MLP: Identical performance, skipping test
# SVM vs Logistic Regression: Identical performance, skipping test
# SVM vs LDA: Identical performance, skipping test
# SVM vs QDA: Identical performance, skipping test
# SVM vs Gaussian Process: Identical performance, skipping test
# SVM vs XGBoost: Identical performance, skipping test
# MLP vs Logistic Regression: Identical performance, skipping test
# MLP vs LDA: Identical performance, skipping test
# MLP vs QDA: Identical performance, skipping test
# MLP vs Gaussian Process: Identical performance, skipping test
# MLP vs XGBoost: Identical performance, skipping test
# Logistic Regression vs LDA: Identical performance, skipping test
# Logistic Regression vs QDA: Identical performance, skipping test
# Logistic Regression vs Gaussian Process: Identical performance, skipping test
# Logistic Regression vs XGBoost: Identical performance, skipping test
# LDA vs QDA: Identical performance, skipping test
# LDA vs Gaussian Process: Identical performance, skipping test
# LDA vs XGBoost: Identical performance, skipping test
# QDA vs Gaussian Process: Identical performance, skipping test
# QDA vs XGBoost: Identical performance, skipping test
# Gaussian Process vs XGBoost: Identical performance, skipping test
# Naive Bayes vs Decision Tree:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs Random Forest:
#   No significant difference (identical performance)
#
# Naive Bayes vs Gradient Boosting:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs AdaBoost:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Naive Bayes vs K-Nearest Neighbors:
#   No significant difference (identical performance)
#
# Naive Bayes vs SVM:
#   No significant difference (identical performance)
#
# Naive Bayes vs MLP:
#   No significant difference (identical performance)
#
# Naive Bayes vs Logistic Regression:
#   No significant difference (identical performance)
#
# Naive Bayes vs LDA:
#   No significant difference (identical performance)
#
# Naive Bayes vs QDA:
#   No significant difference (identical performance)
#
# Naive Bayes vs Gaussian Process:
#   No significant difference (identical performance)
#
# Naive Bayes vs XGBoost:
#   No significant difference (identical performance)
#
# Decision Tree vs Random Forest:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gradient Boosting:
#   Statistic: 7.0
#   p-value: 0.8907458009320663
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs AdaBoost:
#   No significant difference (identical performance)
#
# Decision Tree vs K-Nearest Neighbors:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs SVM:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs MLP:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Logistic Regression:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs LDA:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs QDA:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs Gaussian Process:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Decision Tree vs XGBoost:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs Gradient Boosting:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs AdaBoost:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Random Forest vs K-Nearest Neighbors:
#   No significant difference (identical performance)
#
# Random Forest vs SVM:
#   No significant difference (identical performance)
#
# Random Forest vs MLP:
#   No significant difference (identical performance)
#
# Random Forest vs Logistic Regression:
#   No significant difference (identical performance)
#
# Random Forest vs LDA:
#   No significant difference (identical performance)
#
# Random Forest vs QDA:
#   No significant difference (identical performance)
#
# Random Forest vs Gaussian Process:
#   No significant difference (identical performance)
#
# Random Forest vs XGBoost:
#   No significant difference (identical performance)
#
# Gradient Boosting vs AdaBoost:
#   Statistic: 7.0
#   p-value: 0.8907458009320663
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs K-Nearest Neighbors:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs SVM:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs MLP:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Logistic Regression:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs LDA:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs QDA:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs Gaussian Process:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# Gradient Boosting vs XGBoost:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs K-Nearest Neighbors:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs SVM:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs MLP:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs Logistic Regression:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs LDA:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs QDA:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs Gaussian Process:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# AdaBoost vs XGBoost:
#   Statistic: 5.0
#   p-value: 0.4795001221869535
#   Bonferroni-corrected p-value: 1.0
#   Significant: No
#
# K-Nearest Neighbors vs SVM:
#   No significant difference (identical performance)
#
# K-Nearest Neighbors vs MLP:
#   No significant difference (identical performance)
#
# K-Nearest Neighbors vs Logistic Regression:
#   No significant difference (identical performance)
#
# K-Nearest Neighbors vs LDA:
#   No significant difference (identical performance)
#
# K-Nearest Neighbors vs QDA:
#   No significant difference (identical performance)
#
# K-Nearest Neighbors vs Gaussian Process:
#   No significant difference (identical performance)
#
# K-Nearest Neighbors vs XGBoost:
#   No significant difference (identical performance)
#
# SVM vs MLP:
#   No significant difference (identical performance)
#
# SVM vs Logistic Regression:
#   No significant difference (identical performance)
#
# SVM vs LDA:
#   No significant difference (identical performance)
#
# SVM vs QDA:
#   No significant difference (identical performance)
#
# SVM vs Gaussian Process:
#   No significant difference (identical performance)
#
# SVM vs XGBoost:
#   No significant difference (identical performance)
#
# MLP vs Logistic Regression:
#   No significant difference (identical performance)
#
# MLP vs LDA:
#   No significant difference (identical performance)
#
# MLP vs QDA:
#   No significant difference (identical performance)
#
# MLP vs Gaussian Process:
#   No significant difference (identical performance)
#
# MLP vs XGBoost:
#   No significant difference (identical performance)
#
# Logistic Regression vs LDA:
#   No significant difference (identical performance)
#
# Logistic Regression vs QDA:
#   No significant difference (identical performance)
#
# Logistic Regression vs Gaussian Process:
#   No significant difference (identical performance)
#
# Logistic Regression vs XGBoost:
#   No significant difference (identical performance)
#
# LDA vs QDA:
#   No significant difference (identical performance)
#
# LDA vs Gaussian Process:
#   No significant difference (identical performance)
#
# LDA vs XGBoost:
#   No significant difference (identical performance)
#
# QDA vs Gaussian Process:
#   No significant difference (identical performance)
#
# QDA vs XGBoost:
#   No significant difference (identical performance)
#
# Gaussian Process vs XGBoost:
#   No significant difference (identical performance)
#
#
# 5. Friedman Test
# Chi-square statistic: 10.58823529411758
# p-value: 0.5644968273336584
#
# ==================================================
#
#
# Algorithm vs Algorithm Comparison Table:
#                                       Wins
# Random Forest vs LDA                    11
# Random Forest vs AdaBoost               11
# Gradient Boosting vs AdaBoost            9
# Random Forest vs Logistic Regression     9
# SVM vs QDA                               9
# ...                                    ...
# Naive Bayes vs Gradient Boosting        -8
# Decision Tree vs XGBoost                -9
# Decision Tree vs Random Forest         -11
# Decision Tree vs Gradient Boosting     -11
# Decision Tree vs SVM                   -11
#
# [78 rows x 1 columns]
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
